# %%
import os
import pathlib as path
import numpy as np
import pandas as pd
import cv2
from PIL import Image
from tqdm import tqdm
from glob import iglob
import csv

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from sklearn.metrics import roc_auc_score, mean_absolute_error
from IPython.display import clear_output
# %matplotlib inline

# %%
from torch.utils.data import DataLoader
import torch
from torch import nn
from torch.nn import functional as F
from torchvision.datasets import DatasetFolder
from torch.utils.data import Dataset
from torchvision.transforms.functional import to_tensor

from torch.utils.data.dataset import random_split

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "drive/MyDrive/idao_dataset.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: idao_dataset/train_prep_max/NR/-0.4814000129699707__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev422;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/2.226099967956543__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev813;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/2.202699899673462__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev501;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/3.033900022506714__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev901;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/0.19449999928474426__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev542;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/-1.1181000471115112__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev169;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/-0.34880000352859497__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev700;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/1.4154000282287598__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev791;1-7.png
#   inflating: idao_dataset/train_prep_max/NR/-1.5110000371932983__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev899;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/2.490999937057495__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev222;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/0.8790000081062317__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev177;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/0.6629999876022339__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev237;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/1.3281999826431274__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev800;1-7.png
#   inflating: idao_dataset/train_prep_max/NR/0.19480000436306__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev248;1-3.png
#   inflating: idao_dataset/train_prep_max/NR/2.4405999183654785__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev750;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/1.7108999490737915__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev714;1-3.png
#   inflating: idao_dataset/train_prep_max/NR/0.3894999921321869__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev816;1-2.png
#   inflating: idao_dataset/train_prep_max/NR/-1.8567999601364136__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev907;1-2.png
#   inflating: idao_dataset/train_prep_max/NR/-1.613700032234192__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev450;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/-1.501099944114685__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev798;1-7.png
#   inflating: idao_dataset/train_prep_max/NR/0.4239000082015991__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev609;1-7.png
#   inflating: idao_dataset/train_prep_max/NR/-2.3643999099731445__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev742;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/-1.9881999492645264__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev307;1-2.png
#   inflating: idao_dataset/train_prep_max/NR/0.06759999692440033__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev208;1-3.png
#   inflating: idao_dataset/train_prep_max/NR/1.9186999797821045__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev834;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/-2.055299997329712__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev746;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/1.3863999843597412__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev742;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/-2.047800064086914__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev927;1-3.png
#   inflating: idao_dataset/train_prep_max/NR/-0.04859999939799309__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev524;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/-0.7210000157356262__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev740;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/3.0492000579833984__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev532;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/2.768699884414673__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev918;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/-1.2274999618530273__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev276;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/1.5293999910354614__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev737;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/1.8414000272750854__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev146;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/-0.33250001072883606__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev178;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/1.5174000263214111__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev372;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/-2.959199905395508__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev922;1-7.png
#   inflating: idao_dataset/train_prep_max/NR/-2.966900110244751__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev123;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/0.8388000130653381__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev447;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/-0.4611000120639801__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev795;1-7.png
#   inflating: idao_dataset/train_prep_max/NR/-0.6654000282287598__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev437;1-7.png
#   inflating: idao_dataset/train_prep_max/NR/-3.1105000972747803__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev905;1-2.png
#   inflating: idao_dataset/train_prep_max/NR/-2.756700038909912__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev151;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/-1.944100022315979__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev304;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/0.3528999984264374__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev948;1-7.png
#   inflating: idao_dataset/train_prep_max/NR/1.124899983406067__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev794;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/1.698099970817566__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev211;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/1.926800012588501__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev828;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/1.926800012588501__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev828;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/-1.1473000049591064__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev702;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/-0.07810000330209732__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev265;1-3.png
#   inflating: idao_dataset/train_prep_max/NR/1.0460000038146973__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev973;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/-2.725399971008301__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev522;1-7.png
#   inflating: idao_dataset/train_prep_max/NR/-0.13930000364780426__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev336;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/-1.5707000494003296__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev883;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/-1.243899941444397__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev927;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/-2.257699966430664__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev910;1-2.png
#   inflating: idao_dataset/train_prep_max/NR/-2.624300003051758__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev285;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/1.4206000566482544__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev500;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/2.6113998889923096__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev823;1-3.png
#   inflating: idao_dataset/train_prep_max/NR/2.134500026702881__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev767;1-2.png
#   inflating: idao_dataset/train_prep_max/NR/-2.7458999156951904__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev551;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/2.680000066757202__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev180;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/2.0713000297546387__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev246;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/-1.5443999767303467__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev453;1-7.png
#   inflating: idao_dataset/train_prep_max/NR/2.8750998973846436__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev757;1-3.png
#   inflating: idao_dataset/train_prep_max/NR/1.2583999633789062__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev664;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/3.066699981689453__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev257;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/-0.9046000242233276__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev476;1-3.png
#   inflating: idao_dataset/train_prep_max/NR/-1.0348999500274658__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev314;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/0.9926999807357788__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev982;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/-2.364300012588501__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev432;1-2.png
#   inflating: idao_dataset/train_prep_max/NR/2.5585999488830566__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev431;1-7.png
#   inflating: idao_dataset/train_prep_max/NR/0.5914000272750854__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev583;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/-1.6929999589920044__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev427;1-7.png
#   inflating: idao_dataset/train_prep_max/NR/-2.9495999813079834__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev919;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/-2.9495999813079834__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev919;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/-1.1888999938964844__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev288;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/-2.4614999294281006__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev981;1-3.png
#   inflating: idao_dataset/train_prep_max/NR/-2.4602999687194824__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev903;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/2.7999000549316406__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev861;1-3.png
#   inflating: idao_dataset/train_prep_max/NR/0.2775000035762787__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev764;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/0.2655999958515167__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev296;1-7.png
#   inflating: idao_dataset/train_prep_max/NR/-2.0683999061584473__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev296;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/-0.18279999494552612__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev897;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/0.015300000086426735__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev563;1-3.png
#   inflating: idao_dataset/train_prep_max/NR/0.44690001010894775__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev748;1-2.png
#   inflating: idao_dataset/train_prep_max/NR/-0.625__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev537;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/-0.625__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev537;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/-2.155600070953369__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev639;1-7.png
#   inflating: idao_dataset/train_prep_max/NR/1.4496999979019165__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev405;1-2.png
#   inflating: idao_dataset/train_prep_max/NR/-2.431999921798706__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev646;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/2.009000062942505__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev916;1-2.png
#   inflating: idao_dataset/train_prep_max/NR/1.9768999814987183__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev375;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/2.467099905014038__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev738;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/0.42980000376701355__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev149;1-2.png
#   inflating: idao_dataset/train_prep_max/NR/0.1315000057220459__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev859;1-2.png
#   inflating: idao_dataset/train_prep_max/NR/0.5485000014305115__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev362;1-7.png
#   inflating: idao_dataset/train_prep_max/NR/-1.9687999486923218__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev810;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/-1.0443999767303467__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev916;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/1.215399980545044__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev185;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/2.1282999515533447__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev204;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/2.1282999515533447__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev204;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/2.9605000019073486__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev882;1-2.png
#   inflating: idao_dataset/train_prep_max/NR/-1.2338000535964966__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev920;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/-1.2338000535964966__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev920;1-7.png
#   inflating: idao_dataset/train_prep_max/NR/1.2651000022888184__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev99;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/-1.163599967956543__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev403;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/0.3479999899864197__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev317;1-7.png
#   inflating: idao_dataset/train_prep_max/NR/-2.5236001014709473__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev342;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/-2.5236001014709473__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev342;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/-1.2949999570846558__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev765;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/0.11180000007152557__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev187;1-2.png
#   inflating: idao_dataset/train_prep_max/NR/1.6239999532699585__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev174;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/1.6239999532699585__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev174;1-7.png
#   inflating: idao_dataset/train_prep_max/NR/2.1939001083374023__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev958;1-3.png
#   inflating: idao_dataset/train_prep_max/NR/0.963100016117096__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev738;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/-2.8129000663757324__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev908;1-7.png
#   inflating: idao_dataset/train_prep_max/NR/-0.5461999773979187__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev611;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/-2.1422998905181885__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev805;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/-0.7907999753952026__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev856;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/-0.7907999753952026__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev856;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/-1.0987000465393066__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev855;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/-1.0946999788284302__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev295;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/0.5220999717712402__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev289;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/-3.092900037765503__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev487;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/1.5533000230789185__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev210;1-3.png
#   inflating: idao_dataset/train_prep_max/NR/3.11080002784729__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev493;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/1.8207999467849731__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev712;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/2.347399950027466__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev303;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/-1.9501999616622925__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev283;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/1.9052000045776367__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev450;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/-1.6164000034332275__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev438;1-7.png
#   inflating: idao_dataset/train_prep_max/NR/0.6340000033378601__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev716;1-3.png
#   inflating: idao_dataset/train_prep_max/NR/0.14990000426769257__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev790;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/-1.7806999683380127__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev621;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/-1.1663999557495117__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev360;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/-0.6464999914169312__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev612;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/-0.24899999797344208__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev506;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/-2.7163000106811523__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev353;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/-0.47589999437332153__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev603;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/-2.5497000217437744__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev995;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/-2.5497000217437744__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev995;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/-0.8952000141143799__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev136;1-7.png
#   inflating: idao_dataset/train_prep_max/NR/2.3568999767303467__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev865;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/-1.742900013923645__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev969;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/-2.472599983215332__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev572;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/0.13379999995231628__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev432;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/0.9372000098228455__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev766;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/0.18320000171661377__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev379;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/1.7481000423431396__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev531;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/-0.8105000257492065__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev716;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/0.3199999928474426__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev478;1-7.png
#   inflating: idao_dataset/train_prep_max/NR/2.612799882888794__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev956;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/-2.7939000129699707__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev661;1-3.png
#   inflating: idao_dataset/train_prep_max/NR/-2.746500015258789__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev879;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/-0.4629000127315521__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev764;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/-1.5118999481201172__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev364;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/-1.5118999481201172__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev364;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/-0.07180000096559525__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev971;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/-0.07180000096559525__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev971;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/-3.0220000743865967__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev279;1-3.png
#   inflating: idao_dataset/train_prep_max/NR/-1.5845999717712402__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev467;1-7.png
#   inflating: idao_dataset/train_prep_max/NR/-2.7076001167297363__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev658;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/-0.6338000297546387__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev128;1-3.png
#   inflating: idao_dataset/train_prep_max/NR/1.975600004196167__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev219;1-2.png
#   inflating: idao_dataset/train_prep_max/NR/0.33730000257492065__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev209;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/-0.4839000105857849__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev812;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/0.15680000185966492__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev398;1-3.png
#   inflating: idao_dataset/train_prep_max/NR/-2.263400077819824__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev743;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/1.7728999853134155__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev502;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/-0.48069998621940613__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev557;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/1.9033000469207764__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev870;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/2.362799882888794__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev400;1-2.png
#   inflating: idao_dataset/train_prep_max/NR/-2.1803998947143555__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev385;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/-2.279099941253662__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev978;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/2.4133999347686768__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev840;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/0.7645000219345093__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev180;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/2.152600049972534__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev954;1-7.png
#   inflating: idao_dataset/train_prep_max/NR/-1.1440999507904053__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev919;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/2.4730000495910645__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev314;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/2.9375998973846436__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev672;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/0.5967000126838684__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev746;1-7.png
#   inflating: idao_dataset/train_prep_max/NR/-0.9836000204086304__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev662;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/-0.5730999708175659__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev590;1-3.png
#   inflating: idao_dataset/train_prep_max/NR/-2.1326000690460205__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev178;1-2.png
#   inflating: idao_dataset/train_prep_max/NR/-2.989300012588501__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev568;1-3.png
#   inflating: idao_dataset/train_prep_max/NR/-0.023399999365210533__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev209;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/-0.6096000075340271__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev96;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/0.08839999884366989__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev750;1-3.png
#   inflating: idao_dataset/train_prep_max/NR/-2.4309000968933105__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev219;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/-1.5270999670028687__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev920;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/-0.25450000166893005__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev147;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/-2.266700029373169__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev233;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/1.8803000450134277__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev435;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/-0.7635999917984009__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev865;1-3.png
#   inflating: idao_dataset/train_prep_max/NR/-1.243399977684021__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev570;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/2.910799980163574__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev557;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/2.910799980163574__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev557;1-2.png
#   inflating: idao_dataset/train_prep_max/NR/2.0034000873565674__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev202;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/2.0034000873565674__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev202;1-3.png
#   inflating: idao_dataset/train_prep_max/NR/0.2621000111103058__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev559;1-7.png
#   inflating: idao_dataset/train_prep_max/NR/0.5615000128746033__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev556;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/2.8815999031066895__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev160;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/2.728300094604492__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev323;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/1.6615999937057495__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev506;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/1.6615999937057495__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev506;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/-0.972599983215332__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev252;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/2.2430999279022217__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev969;1-7.png
#   inflating: idao_dataset/train_prep_max/NR/-0.364300012588501__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev89;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/-0.26829999685287476__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev80;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/2.438499927520752__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev819;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/-0.17820000648498535__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev276;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/0.09430000185966492__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev545;1-3.png
#   inflating: idao_dataset/train_prep_max/NR/0.09430000185966492__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev545;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/0.8931000232696533__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev612;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/-0.13189999759197235__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev152;1-7.png
#   inflating: idao_dataset/train_prep_max/NR/1.0910999774932861__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev738;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/-1.32669997215271__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev816;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/2.0099000930786133__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev500;1-7.png
#   inflating: idao_dataset/train_prep_max/NR/0.6247000098228455__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev412;1-3.png
#   inflating: idao_dataset/train_prep_max/NR/-1.555999994277954__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev780;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/1.8646999597549438__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev817;1-7.png
#   inflating: idao_dataset/train_prep_max/NR/0.9053999781608582__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev548;1-7.png
#   inflating: idao_dataset/train_prep_max/NR/-1.167199969291687__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev889;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/-3.0827999114990234__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev568;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/-1.8726999759674072__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev342;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/1.7002999782562256__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev519;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/0.953000009059906__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev659;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/-1.9113999605178833__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev745;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/-1.9113999605178833__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev745;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/-1.4213000535964966__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev603;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/2.591399908065796__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev116;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/0.7908999919891357__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev724;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/-1.611899971961975__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev116;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/-2.56850004196167__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev670;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/2.978800058364868__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev920;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/-1.0463000535964966__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev997;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/2.977299928665161__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev463;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/-2.6953001022338867__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev487;1-3.png
#   inflating: idao_dataset/train_prep_max/NR/0.477400004863739__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev747;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/-0.705299973487854__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev223;1-3.png
#   inflating: idao_dataset/train_prep_max/NR/1.9124000072479248__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev509;1-2.png
#   inflating: idao_dataset/train_prep_max/NR/2.551300048828125__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev933;1-2.png
#   inflating: idao_dataset/train_prep_max/NR/0.5511999726295471__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev494;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/-0.35580000281333923__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev642;1-7.png
#   inflating: idao_dataset/train_prep_max/NR/-2.768699884414673__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev375;1-3.png
#   inflating: idao_dataset/train_prep_max/NR/-0.5123999714851379__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev994;1-3.png
#   inflating: idao_dataset/train_prep_max/NR/-2.96560001373291__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev503;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/0.7257000207901001__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev724;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/2.5594000816345215__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev418;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/-1.1197999715805054__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev225;1-2.png
#   inflating: idao_dataset/train_prep_max/NR/-0.7217000126838684__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev649;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/1.3037999868392944__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev986;1-2.png
#   inflating: idao_dataset/train_prep_max/NR/1.3037999868392944__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev986;1-7.png
#   inflating: idao_dataset/train_prep_max/NR/-1.1974999904632568__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev751;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/0.6216999888420105__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev806;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/0.03280000016093254__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev413;1-2.png
#   inflating: idao_dataset/train_prep_max/NR/-2.65939998626709__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev104;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/-0.1436000019311905__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev242;1-7.png
#   inflating: idao_dataset/train_prep_max/NR/-0.16019999980926514__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev415;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/-0.8652999997138977__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev136;1-7.png
#   inflating: idao_dataset/train_prep_max/NR/2.416100025177002__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev515;1-3.png
#   inflating: idao_dataset/train_prep_max/NR/-0.29980000853538513__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev387;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/-0.43479999899864197__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev533;1-3.png
#   inflating: idao_dataset/train_prep_max/NR/-1.756700038909912__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev750;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/1.5332000255584717__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev615;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/3.0782999992370605__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev543;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/-2.0028998851776123__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev767;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/-2.0028998851776123__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev767;1-2.png
#   inflating: idao_dataset/train_prep_max/NR/1.4696999788284302__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev112;1-2.png
#   inflating: idao_dataset/train_prep_max/NR/2.3938000202178955__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev719;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/0.7663999795913696__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev651;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/2.6816000938415527__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev508;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/2.6106998920440674__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev93;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/2.4453999996185303__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev974;1-3.png
#   inflating: idao_dataset/train_prep_max/NR/2.159600019454956__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev453;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/-2.4971001148223877__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev715;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/-0.5169000029563904__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev690;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/-2.400899887084961__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev101;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/0.5697000026702881__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev667;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/-0.9624999761581421__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev722;1-7.png
#   inflating: idao_dataset/train_prep_max/NR/0.9537000060081482__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev842;1-7.png
#   inflating: idao_dataset/train_prep_max/NR/1.9271999597549438__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev616;1-3.png
#   inflating: idao_dataset/train_prep_max/NR/1.0673999786376953__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev619;1-3.png
#   inflating: idao_dataset/train_prep_max/NR/0.42289999127388__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev125;1-7.png
#   inflating: idao_dataset/train_prep_max/NR/-2.8698999881744385__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev914;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/2.303499937057495__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev274;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/1.9424999952316284__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev361;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/-2.632499933242798__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev491;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/-2.540800094604492__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev133;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/-0.20229999721050262__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev169;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/-2.3907999992370605__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev222;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/2.011899948120117__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev483;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/2.011899948120117__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev483;1-7.png
#   inflating: idao_dataset/train_prep_max/NR/-2.940999984741211__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev989;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/-1.1131999492645264__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev949;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/-1.1016000509262085__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev686;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/-1.7519999742507935__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev370;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/-2.7011001110076904__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev176;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/-1.3697999715805054__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev322;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/2.6709001064300537__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev497;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/2.7571001052856445__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev403;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/1.0293999910354614__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev570;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/1.4840999841690063__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev975;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/2.544300079345703__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev182;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/0.8999000191688538__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev394;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/-3.073899984359741__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev497;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/-2.650099992752075__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev179;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/2.9505999088287354__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev932;1-7.png
#   inflating: idao_dataset/train_prep_max/NR/-2.154400110244751__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev765;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/2.165299892425537__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev983;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/2.6445000171661377__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev202;1-2.png
#   inflating: idao_dataset/train_prep_max/NR/0.024000000208616257__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev164;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/1.7452000379562378__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev654;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/2.196500062942505__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev855;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/1.0444999933242798__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev470;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/1.0444999933242798__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev470;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/1.906999945640564__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev585;1-3.png
#   inflating: idao_dataset/train_prep_max/NR/0.9814000129699707__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev137;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/0.8561999797821045__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev257;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/1.975100040435791__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev278;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/-0.6468999981880188__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev239;1-7.png
#   inflating: idao_dataset/train_prep_max/NR/-1.1390999555587769__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev381;1-7.png
# ...
#   inflating: idao_dataset/train_prep_max/NR/-2.9312000274658203__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev836;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/-3.1064000129699707__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev141;1-3.png
#   inflating: idao_dataset/train_prep_max/NR/-1.6789000034332275__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev269;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/-2.8645999431610107__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev594;1-3.png
#   inflating: idao_dataset/train_prep_max/NR/-0.42170000076293945__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev89;1-2.png
#   inflating: idao_dataset/train_prep_max/NR/0.023900000378489494__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev634;1-3.png
#   inflating: idao_dataset/train_prep_max/NR/1.42739999294281__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev397;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/-0.14300000667572021__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev253;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/1.8493000268936157__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev934;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/-0.6751999855041504__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev502;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/-2.540800094604492__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev133;1-3.png
#   inflating: idao_dataset/train_prep_max/NR/-0.7190999984741211__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev348;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/-0.9901999831199646__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev108;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/-1.3697999715805054__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev322;1-3.png
#   inflating: idao_dataset/train_prep_max/NR/1.7002999782562256__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev910;1-3.png
#   inflating: idao_dataset/train_prep_max/NR/-3.073899984359741__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev497;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/-0.03550000116229057__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev230;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/-1.948799967765808__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev431;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/-1.1658999919891357__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev108;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/-1.6052000522613525__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev653;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/-1.6052000522613525__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev653;1-2.png
#   inflating: idao_dataset/train_prep_max/NR/1.8773000240325928__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev513;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/-2.910900115966797__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev505;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/-2.6803998947143555__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev169;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/1.4829000234603882__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev929;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/-0.9639999866485596__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev372;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/-1.1481000185012817__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev638;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/0.5013999938964844__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev562;1-7.png
#   inflating: idao_dataset/train_prep_max/NR/-0.1005999967455864__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev261;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/-1.3335000276565552__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev781;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/1.2726000547409058__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev897;1-2.png
#   inflating: idao_dataset/train_prep_max/NR/2.6168999671936035__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev851;1-2.png
#   inflating: idao_dataset/train_prep_max/NR/-1.8675999641418457__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev866;1-7.png
#   inflating: idao_dataset/train_prep_max/NR/-1.2944999933242798__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev976;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/0.98580002784729__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev274;1-2.png
#   inflating: idao_dataset/train_prep_max/NR/1.4105000495910645__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev269;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/-0.24169999361038208__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev380;1-3.png
#   inflating: idao_dataset/train_prep_max/NR/-1.7174999713897705__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev874;1-7.png
#   inflating: idao_dataset/train_prep_max/NR/-1.7075999975204468__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev439;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/-0.5735999941825867__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev500;1-2.png
#   inflating: idao_dataset/train_prep_max/NR/0.9075999855995178__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev195;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/-2.655400037765503__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev517;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/-1.3504999876022339__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev625;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/2.031399965286255__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev640;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/-1.207800030708313__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev283;1-2.png
#   inflating: idao_dataset/train_prep_max/NR/2.7184998989105225__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev652;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/-0.7746000289916992__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev842;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/-2.427299976348877__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev491;1-2.png
#   inflating: idao_dataset/train_prep_max/NR/-3.073899984359741__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev786;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/-0.38929998874664307__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev920;1-7.png
#   inflating: idao_dataset/train_prep_max/NR/-0.9028000235557556__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev979;1-3.png
#   inflating: idao_dataset/train_prep_max/NR/-0.10040000081062317__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev600;1-2.png
#   inflating: idao_dataset/train_prep_max/NR/-2.3815999031066895__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev322;1-2.png
#   inflating: idao_dataset/train_prep_max/NR/-2.1621999740600586__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev711;1-3.png
#   inflating: idao_dataset/train_prep_max/NR/1.4474999904632568__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev178;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/2.0876998901367188__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev599;1-2.png
#   inflating: idao_dataset/train_prep_max/NR/0.06109999865293503__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev150;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/0.06109999865293503__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev150;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/2.473099946975708__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev791;1-2.png
#   inflating: idao_dataset/train_prep_max/NR/0.9047999978065491__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev302;1-2.png
#   inflating: idao_dataset/train_prep_max/NR/-0.384799987077713__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev960;1-7.png
#   inflating: idao_dataset/train_prep_max/NR/-0.8618999719619751__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev363;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/-0.7038999795913696__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev118;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/-1.9214999675750732__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev326;1-7.png
#   inflating: idao_dataset/train_prep_max/NR/-0.7013000249862671__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev795;1-7.png
#   inflating: idao_dataset/train_prep_max/NR/-2.2397000789642334__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev718;1-7.png
#   inflating: idao_dataset/train_prep_max/NR/1.545799970626831__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev553;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/1.7698999643325806__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev417;1-3.png
#   inflating: idao_dataset/train_prep_max/NR/-2.5764999389648438__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev166;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/1.0422999858856201__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev855;1-3.png
#   inflating: idao_dataset/train_prep_max/NR/-1.4752000570297241__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev787;1-2.png
#   inflating: idao_dataset/train_prep_max/NR/-0.6471999883651733__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev372;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/-2.6949000358581543__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev367;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/2.2571001052856445__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev995;1-2.png
#   inflating: idao_dataset/train_prep_max/NR/-2.995300054550171__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev162;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/-0.9869999885559082__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev308;1-3.png
#   inflating: idao_dataset/train_prep_max/NR/-0.14339999854564667__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev846;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/-1.454699993133545__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev289;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/-1.454699993133545__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev289;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/-0.9724000096321106__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev136;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/2.4916999340057373__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev927;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/-0.9039000272750854__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev251;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/-2.341399908065796__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev203;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/2.748300075531006__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev864;1-3.png
#   inflating: idao_dataset/train_prep_max/NR/1.1629999876022339__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev938;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/-1.6789000034332275__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev550;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/-1.524399995803833__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev856;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/-1.1789000034332275__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev635;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/-0.4189999997615814__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev811;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/-0.26179999113082886__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev672;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/0.9208999872207642__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev682;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/-1.399399995803833__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev192;1-2.png
#   inflating: idao_dataset/train_prep_max/NR/-0.7760000228881836__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev187;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/-0.5174999833106995__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev887;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/2.728800058364868__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev629;1-3.png
#   inflating: idao_dataset/train_prep_max/NR/2.837899923324585__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev814;1-3.png
#   inflating: idao_dataset/train_prep_max/NR/-3.1008999347686768__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev993;1-7.png
#   inflating: idao_dataset/train_prep_max/NR/-0.5705000162124634__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev783;1-2.png
#   inflating: idao_dataset/train_prep_max/NR/-0.520799994468689__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev144;1-2.png
#   inflating: idao_dataset/train_prep_max/NR/0.9330000281333923__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev310;1-5.png
#   inflating: idao_dataset/train_prep_max/NR/-2.9084999561309814__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev325;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/1.1101000308990479__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev260;1-0.png
#   inflating: idao_dataset/train_prep_max/NR/0.4018000066280365__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev538;1-1.png
#   inflating: idao_dataset/train_prep_max/NR/1.3973000049591064__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev963;1-6.png
#   inflating: idao_dataset/train_prep_max/NR/1.3416999578475952__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev742;1-2.png
#   inflating: idao_dataset/train_prep_max/NR/-0.6550999879837036__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev617;1-4.png
#   inflating: idao_dataset/train_prep_max/NR/-1.9801000356674194__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev936;1-7.png
#   inflating: idao_dataset/private_test_prep.zip
#   inflating: idao_dataset/public_test_prep.zip

# %%
if torch.cuda.is_available():
    print("True")
    torch.set_default_tensor_type('torch.cuda.FloatTensor')
# Out:
# True

# %% [markdown]
# #### Dataloader

# %%
def img_loader(path: str):
    return cv2.imread(path, cv2.IMREAD_UNCHANGED)

# %%
def name_to_energy(name):
    try:
        names = os.path.split(name)[-1].split("_")
        idx = [i for i, v in enumerate(names) if v == "keV"][0]
        return torch.tensor(float(names[idx - 1]))
    except Exception as e:
        return torch.tensor(-1.0)

# %%
#def name_to_index(self, name):
#   return os.path.split(name)[-1].split('.')[0]

# %%
def name_to_label(name):
    try:
        names = os.path.split(name)[-1].split("_")
        for name in names:
            if name=="ER":
                return torch.tensor(1)
            elif name=="NR":
                return torch.tensor(0)
    except Exception as e:
        return torch.tensor(-1.0)

# %%
class IDAODataset(Dataset):
    
    def __init__(self, main_dir, mode: ["classification", "regression"] = "classification", img_size=300):
        self.img_loader = img_loader
        self.mode = mode
        self.img_size = img_size
        self.all_imgs = list(iglob(main_dir + "**/*.png"))

    def __len__(self):
        return len(self.all_imgs)

    def __getitem__(self, idx):
        img_name = self.all_imgs[idx]
        res_img = self.img_loader(img_name)
        res_img = torch.reshape(to_tensor(np.expand_dims(res_img, axis=0)), (1, self.img_size, self.img_size))
        if self.mode == "classification":
            res_target = name_to_label(img_name)
        else:
            res_target = name_to_energy(img_name)
        return res_img, res_target

# %%
class SplitDataset(Dataset):
    def __init__(self, subset, transform=None):
        self.subset = subset
        self.transform = transform
        
    def __getitem__(self, index):
        x, y = self.subset[index]
        if self.transform:
            x = self.transform(x)
        x, y = x.cuda(), y.cuda()
        return x, y
        
    def __len__(self):
        return len(self.subset)

# %% [markdown]
# #### Datasets

# %%
main_dir = "idao_dataset/train_prep_max/"

# %%
def split_dataset(dataset, val_part=0.05):
    percet_20 = int(val_part*len(dataset))
    train_set, val_set = random_split(
        dataset, [len(dataset)-percet_20, percet_20], generator=torch.Generator(device='cuda:0').manual_seed(666)
    )
    return train_set, val_set

# %% [markdown]
# #### Model

# %% [markdown]
# All model architecture here

# %%
class SimpleConv(nn.Module):
    
    def __init__(self, mode: ["classification", "regression"] = "classification"):
        super(SimpleConv, self).__init__()
        self.mode = mode
        self.layer1 = nn.Sequential(
            nn.Conv2d(1, 8, kernel_size=5, stride=1, padding=2), # -> 300*300*8
            nn.BatchNorm2d(8),
            nn.ReLU(), 
            nn.MaxPool2d(kernel_size=10, stride=10), # -> 30*30*8
            nn.Conv2d(8, 16, kernel_size=3, stride=1, padding=1), # -> 30*30*16
            nn.BatchNorm2d(16),
            nn.ReLU(), 
            nn.MaxPool2d(kernel_size=3, stride=3), # -> 10*10*16
            nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1), # -> 10*10*32
            nn.BatchNorm2d(32),
            nn.ReLU(), 
            nn.Flatten(), 
        )
        
        self.fc = nn.Sequential( # for classification
            nn.Linear(3200, 1600),
            nn.ReLU(), 
            nn.Dropout(),
            nn.Linear(1600, 500),
            nn.ReLU(), 
            nn.Dropout(),
            nn.Linear(500, 1),
        )
        #self.fc2 = nn.Sequential( # for regression
        #    nn.ReLU(), 
        #    nn.Dropout(),
        #    nn.Linear(500, 1),
        #)
        
        self.stem = nn.Sequential(
            self.layer1, 
            nn.Dropout(), 
            self.fc,
            )
        if self.mode == "classification":
            self.classification = nn.Sequential(self.stem, nn.Sigmoid())
        else:
            self.regression = self.stem
    
    def forward(self, x):
        if self.mode == "classification":
            x = self.classification(x)
        else:
            x = self.regression(x)
        return x

# %% [markdown]
# Just train loop  -  nothing interesting

# %%
def train(network, train_loader, val_loader, epochs, learning_rate,
          mode: ["classification", "regression"] = "classification"):
    
    # init 
    if mode == "classification":
        loss = nn.BCELoss()
    else:
        loss = nn.L1Loss() # MAE
    optimizer = torch.optim.Adam(network.parameters(), lr=learning_rate)
    train_loss_epochs = []
    test_loss_epochs = []
    train_accuracy_epochs = []
    test_accuracy_epochs = []

    if mode == "classification":
        best_acc = 0
    else:
        best_acc = 100000
    
    # train loop
    try:
        for epoch in range(epochs):
            
            # epoch train
            losses = []
            accuracies = []
            network.train()
            for X, y in train_loader:
                optimizer.zero_grad()
                prediction = network(X)
                y = y.view(-1, 1)
                loss_batch = loss(prediction, y.float())
                losses.append(loss_batch.item())
                y = y.cpu().data.numpy()
                loss_batch.backward()                
                optimizer.step()

                y_pred = prediction.cpu().data.numpy()
                if mode == "classification":
                    y_pred[y_pred > 0.5] = 1
                    y_pred[y_pred <= 0.5] = 0
                    accuracies.append((y_pred==y).mean())
                else:
                    y_pred[y_pred <= 1.5] = 1 
                    y_pred[np.logical_and(y_pred > 1.5, y_pred < 4.5)] = 3
                    y_pred[np.logical_and(y_pred >= 4.5, y_pred < 8)] = 6
                    y_pred[np.logical_and(y_pred >= 8, y_pred < 15)] = 10
                    y_pred[np.logical_and(y_pred >= 15, y_pred < 25)] = 20
                    y_pred[y_pred >= 25] = 30
                    accuracies.append(mean_absolute_error(y, y_pred))
            train_loss_epochs.append(np.mean(losses))
            train_accuracy_epochs.append(np.mean(accuracies))
            
            # epoch validation
            losses = []
            accuracies = []
            network.eval()
            with torch.no_grad():
                for X, y in val_loader:
                    prediction = network(X)
                    y = y.view(-1, 1)
                    loss_batch = loss(prediction, y.float())
                    losses.append(loss_batch.item())        
                    y = y.cpu().data.numpy()        
                    y_pred = prediction.cpu().data.numpy()
                    if mode == "classification":
                        y_pred[y_pred > 0.5] = 1
                        y_pred[y_pred <= 0.5] = 0
                        accuracies.append((y_pred==y).mean())
                    else:
                        y_pred[y_pred <= 1.5] = 1 
                        y_pred[np.logical_and(y_pred > 1.5, y_pred < 4.5)] = 3
                        y_pred[np.logical_and(y_pred >= 4.5, y_pred < 8)] = 6
                        y_pred[np.logical_and(y_pred >= 8, y_pred < 15)] = 10
                        y_pred[np.logical_and(y_pred >= 15, y_pred < 25)] = 20
                        y_pred[y_pred >= 25] = 30
                        accuracies.append(mean_absolute_error(y, y_pred))
            test_loss_epochs.append(np.mean(losses))
            test_accuracy_epochs.append(np.mean(accuracies))
            
            # save best model
            if mode == "classification":
                if best_acc < test_accuracy_epochs[-1]:
                    torch.save(network.state_dict(), "best_class.pickle")
                    best_acc = test_accuracy_epochs[-1]
                    upd = True
                else:
                    upd = False
            else:
                if best_acc > test_accuracy_epochs[-1]:
                    torch.save(network.state_dict(), "best_reg.pickle")
                    best_acc = test_accuracy_epochs[-1]
                    upd = True
                else:
                    upd = False


            # draw
            clear_output(True)
            if mode == "classification":
                print('\rEpoch {0}... (Train/Test) BCE: {1:.3f}/{2:.3f}\tAccuracy: {3:.3f}/{4:.3f}\t best_acc: {5:.3f}, upd: {6}'.format(
                            epoch, train_loss_epochs[-1], test_loss_epochs[-1],
                            train_accuracy_epochs[-1], test_accuracy_epochs[-1], best_acc, upd))
            else:
                print('\rEpoch {0}... (Train/Test) MAE: {1:.3f}/{2:.3f}\tMAE after rounding: {3:.3f}/{4:.3f}\t best_acc: {5:.3f}, upd: {6}'.format(
                            epoch, train_loss_epochs[-1], test_loss_epochs[-1],
                            train_accuracy_epochs[-1], test_accuracy_epochs[-1], best_acc, upd))
            plt.figure(figsize=(12, 5))
            plt.subplot(1, 2, 1)
            plt.plot(train_loss_epochs, label='Train')
            plt.plot(test_loss_epochs, label='Test')
            plt.xlabel('Epochs', fontsize=16)
            plt.ylabel('Loss', fontsize=16)
            plt.legend(loc=0, fontsize=16)
            plt.grid()
            plt.subplot(1, 2, 2)
            if mode == "classification":
                plt.plot(train_accuracy_epochs, label='Train Accuracy')
                plt.plot(test_accuracy_epochs, label='Test Accuracy')
                plt.ylabel('Accuracy', fontsize=16)
            else:
                plt.plot(train_accuracy_epochs, label='Train MAE')
                plt.plot(test_accuracy_epochs, label='Test MAE')
                plt.ylabel('Loss', fontsize=16)
            plt.xlabel('Epochs', fontsize=16)
            plt.legend(loc=0, fontsize=16)
            plt.grid()
            plt.show()
    except KeyboardInterrupt:
        pass

# %% [markdown]
# # Train network

# %% [markdown]
# #### Classification

# %%
mode = "classification"

# %% [markdown]
# Init dataset

# %%
class_dataset = IDAODataset(main_dir, mode)

# %%
class_train_set, class_val_set = split_dataset(class_dataset)

# %%
class_train_dataset = SplitDataset(class_train_set)
class_val_dataset = SplitDataset(class_val_set)

# %%
class_train_loader = DataLoader(class_train_dataset, batch_size=500,
                        shuffle=True, num_workers=0)
class_val_loader = DataLoader(class_val_dataset, batch_size=500,
                        shuffle=True, num_workers=0)

# %% [markdown]
# Init model

# %%
class_model = SimpleConv(mode)
if torch.cuda.is_available():
    print("True")
    class_model.cuda()
# Out:
# True

# %% [markdown]
# Train model

# %%
train(class_model, class_train_loader, class_val_loader, 7, 0.001, mode)
# Out:
# Epoch 3... (Train/Test) BCE: 0.012/0.012	Accuracy: 0.996/0.996	 best_acc: 0.996, upd: True

# %% [markdown]
# #### Regression

# %%
mode = "regression"

# %% [markdown]
# Init dataset

# %%
reg_dataset = IDAODataset(main_dir, mode)

# %%
reg_train_set, reg_val_set = split_dataset(reg_dataset)

# %%
reg_train_dataset = SplitDataset(reg_train_set)
reg_val_dataset = SplitDataset(reg_val_set)

# %%
reg_train_loader = DataLoader(reg_train_dataset, batch_size=500,
                        shuffle=True, num_workers=0)
reg_val_loader = DataLoader(reg_val_dataset, batch_size=500,
                        shuffle=True, num_workers=0)

# %% [markdown]
# Init model

# %%
reg_model = SimpleConv(mode)
if torch.cuda.is_available():
    reg_model.cuda()

# %% [markdown]
# Train model

# %%
train(reg_model, reg_train_loader, reg_val_loader, 8, 0.001, mode)
# Out:
# Epoch 7... (Train/Test) MAE: 1.167/0.632	MAE after rounding: 0.300/0.053	 best_acc: 0.053, upd: True

# %% [markdown]
# ### Submition

# %%
#df = pd.read_csv("track1_predictions_example.csv")

# %%
#df.head()

# %%
#df.shape

# %%
public_path = "idao_dataset/public_test_prep/"
private_path = "idao_dataset/private_test_prep/"

# %%
public_test = os.listdir(public_path)
private_test = os.listdir(private_path)

# %%
len(public_test), len(private_test)
# Out:
# (1502, 15062)

# %%
def submit(class_model, reg_model, threshold=0.5, round_on=False):
    with open('my_submission.csv' , 'wt') as fout:
        writer = csv.writer(fout)
        writer.writerow(['id','classification_predictions','regression_predictions'])
        # public
        for name in public_test:
            img = cv2.imread(public_path + name, cv2.IMREAD_UNCHANGED)
            res_img = torch.reshape(to_tensor(img), (1, 1, img.shape[0], img.shape[1]))
            res_img = res_img.cuda()
            # classification
            class_res = int(class_model.forward(res_img)>threshold)
            # regression
            reg_res = reg_model.forward(res_img)
            if round_on:
                if reg_res <= 1.5:
                    reg_res = 1.0
                elif reg_res <= 4.5:
                    reg_res = 3.0
                elif reg_res <= 8.0:
                    reg_res = 6.0
                elif reg_res <= 15.0:
                    reg_res = 10.0
                elif reg_res <= 25.0:
                    reg_res = 20.0
                else:
                    reg_res = 30.0
            else:
                if reg_res < 1.0:
                    reg_res = 1.0
                elif reg_res > 30.0:
                    reg_res = 30.0
                else:
                    reg_res = float(reg_res)
            # write
            writer.writerow([name[:-4], class_res, reg_res])
        # private
        for name in private_test:
            img = cv2.imread(private_path + name, cv2.IMREAD_UNCHANGED)
            res_img = torch.reshape(to_tensor(img), (1, 1, img.shape[0], img.shape[1]))
            res_img = res_img.cuda()
            # classification
            class_res = int(class_model.forward(res_img)>threshold)
            # regression
            reg_res = reg_model.forward(res_img)
            if round_on:
                if reg_res <= 1.5:
                    reg_res = 1.0
                elif reg_res <= 4.5:
                    reg_res = 3.0
                elif reg_res <= 8.0:
                    reg_res = 6.0
                elif reg_res <= 15.0:
                    reg_res = 10.0
                elif reg_res <= 25.0:
                    reg_res = 20.0
                else:
                    reg_res = 30.0
            else:
                if reg_res < 1.0:
                    reg_res = 1.0
                elif reg_res > 30.0:
                    reg_res = 30.0
                else:
                    reg_res = float(reg_res)
            # write
            writer.writerow([name[:-4], class_res, reg_res])

# %%
class_best = SimpleConv("classification")
class_best.load_state_dict(torch.load("best_class.pickle"))
# Out:
# <All keys matched successfully>

# %%
reg_best = SimpleConv("regression")
reg_best.load_state_dict(torch.load("best_reg.pickle"))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ~5 minutes...

# %%
submit(class_model, reg_model, round_on=True)

# %%
my_df = pd.read_csv("my_submission.csv")

# %%
my_df.head()
# Out:
#                                          id  ...  regression_predictions
# 0  870fa05023ba40ece55c8886ad3ae051853630fa  ...                     1.0
# 1  787df31c1e7815855a2e04b60d15d17b6ed43df2  ...                     3.0
# 2  5e08d39087d25c07222105d4d0aad94a275d6dcb  ...                     6.0
# 3  a8771be97c39e754ba35f1dacd9cfafe7bc9183c  ...                    30.0
# 4  c8bba7ea2625a956b2a47525026768a1ea141eec  ...                    30.0
#
# [5 rows x 3 columns]

# %%
my_df.shape
