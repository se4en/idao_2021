# %%
from PIL import Image

import matplotlib.pyplot as plt
import os
import numpy as np

from skimage import io, color
from skimage.transform import rescale, resize, downscale_local_mean

# %%
test_path = os.listdir("idao_dataset/train/NR/")[100]

# %%
# Out:
# '1.5061999559402466__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev546;1.png'

# %%
img = Image.open("idao_dataset/train/NR/" + test_path)

# %%
img.show()

# %%
# Out:
# numpy.ndarray

# %%
img = io.imread("idao_dataset/train/NR/" + test_path, as_gray=True)

# %%
plt.imshow(img)

# %%
norm_img = img/np.linalg.norm(img)

# %%
img.shape, norm_img.shape
# Out:
# ((576, 576), (576, 576))

# %%
norm_img
# Out:
# array([[0.00172859, 0.00165944, 0.00179773, ..., 0.0017113 , 0.00172859,
#         0.00167673],
#        [0.00178044, 0.00172859, 0.00169401, ..., 0.0017113 , 0.00174587,
#         0.00172859],
#        [0.00179773, 0.00169401, 0.00178044, ..., 0.00186687, 0.00169401,
#         0.0017113 ],
#        ...,
#        [0.00181502, 0.00176316, 0.00178044, ..., 0.00178044, 0.00176316,
#         0.0017113 ],
#        [0.00174587, 0.00167673, 0.00179773, ..., 0.00174587, 0.00172859,
#         0.00169401],
#        [0.00174587, 0.00172859, 0.00172859, ..., 0.00179773, 0.00174587,
#         0.00174587]])

# %%
plt.imshow(norm_img)
